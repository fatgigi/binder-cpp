// %%
#include<iostream>
#include<string>

// %%
std::string str;
str.append("ab");
std::cout<< str << '\n';
// Out:
// ab

// %%
str.append(" print out this line", 5);
std::cout<< str << '\n';
// Out:
// ab prin

// %%
std::string str2;
std::string str3="print 10 and then 5 more";
str2.append(str3.begin() + 8, str3.end());
std::cout << str2 << '\n';
// Out:
//  and then 5 more

// %%
std::cout << typeid(str[0]).name() << '\n';
// Out:
// c
